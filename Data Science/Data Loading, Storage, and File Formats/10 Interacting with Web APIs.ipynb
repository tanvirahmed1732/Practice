# %%
import numpy as np
import pandas as pd
import requests

url = "https://api.github.com/repos/pandas-dev/pandas/issues"
resp = requests.get(url) #get http request
resp.raise_for_status()
resp
data=resp.json()
data[0]["title"]
issues=pd.DataFrame(data,columns=["numbers","title","labels","state"])
issues
# Out:
#     numbers                                              title  \
# 0       NaN  TST(string dtype): Resolve xfails in stack_uns...
# 1       NaN           ENH: Enable .mode to sort with NA values
# 2       NaN  TST(str dtype): Resolve xfail in test_value_co...
# 3       NaN  TST(string dtype): Resolve xfail in test_find_...
# 4       NaN  BUG: quoting=csv.QUOTE_NONNUMERIC adds extra d...
# 5       NaN  Format `decimal.Decimal` as full precision str...
# 6       NaN  ENH: Support pipe() method in Rolling and Expa...
# 7       NaN     ENH: Expose NoDefault in pandas.api.extensions
# 8       NaN  BUG: Series constructor from dictionary drops ...
# 9       NaN  TST(string dtype): Resolve xfails in test_from...
# 10      NaN  ENH: add `__rshift__`, `__lshift__`, `__irshif...
# 11      NaN  ENH: Make pd.Timestamp.astimezone() default to...
# 12      NaN  ENH: frozensets are shown in parentheses (like...
# 13      NaN                   Remove editable installs from CI
# ...
