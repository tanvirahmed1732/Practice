# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

s=pd.Series(np.random.standard_normal(10).cumsum(), index=np.arange(0,100,10))
s.plot()

df=pd.DataFrame(np.random.standard_normal((10,4)).cumsum(0), columns=['A','B','C','D'],
index=np.arange(0,100,10))
plt.style.use('grayscale')
df.plot()
df
# Out:
#            A         B         C         D
# 0   0.537048 -2.288955 -0.399627 -0.577314
# 10 -0.242076 -1.508940 -0.349993 -0.505362
# 20 -0.041623 -2.913748  0.895387 -1.891743
# 30  1.409093 -2.582503  0.910276 -2.451915
# 40 -0.533974 -1.889628  1.422411 -3.372550
# 50 -0.937519 -2.740961  0.303347 -4.081348
# 60 -0.528581 -2.778413 -0.236039 -2.845407
# 70 -1.080821 -1.981471 -0.876031 -2.710066
# 80 -2.325303 -2.412018  0.470203 -2.510410
# 90 -2.344002 -1.201714  0.332205 -3.465402
