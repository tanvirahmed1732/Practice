# %%
import pandas as pd

# %%
bios=pd.read_csv("bios.csv")

# %%
bios.head(10)
# df.info()
# df.tail
# Out:
#    athlete_id                   name   born_date          born_city  \
# 0           1  Jean-François Blanchy  1886-12-12           Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01             Meulan
# 2           3           Jean Borotra  1898-08-13           Biarritz
# 3           4        Jacques Brugnon  1895-05-11        Paris VIIIe
# 4           5           Albert Canet  1878-04-17         Wandsworth
# 5           6      Nicolas Chatelain  1970-01-13             Amiens
# 6           7          Patrick Chila  1969-11-27        Ris-Orangis
# 7           8           Henri Cochet  1901-12-14       Villeurbanne
# 8           9          Marcel Cousin  1896-08-04              Nîmes
# 9          10     Guy de la Chapelle  1868-07-16  Farges-Allichamps
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# ...

# %%
bios.loc[bios["height_cm"]>220,['name','height_cm']]
bios[bios["height_cm"]>220][['name','height_cm']] #same
# Out:
#                    name  height_cm
# 5673     Gunther Behnke      221.0
# 5781     Tommy Burleson      223.0
# 6978    Arvydas Sabonis      223.0
# 89070          Yao Ming      226.0
# 89075    Roberto Dueñas      221.0
# 120266     Zhang Zhaoxu      221.0

# %%
#important
bios[bios["name"].str.contains("tanvir|riyan",case=False)] #with the case, we can turn off case sensitivity
#"|" means "or"
# Out:
#         athlete_id                         name   born_date  \
# 252            253               Hariyanto Arbi  1972-01-21
# 1881          1891  Nurfitriyana Saiman-Lantang  1962-03-07
# 5490          5511           Mariyana Chobanova  1965-09-13
# 19839        19978                   Tanvir Dar  1937-06-04
# 35630        35911           Mariyana Yankulova  1969-08-23
# 35641        35923            Mariyana Mincheva  1959-11-06
# 56966        57372              Mariyan Avramov  1965-04-13
# 75099        75675            Sriyani Kulawansa  1970-03-01
# 75100        75676      Sriyani Dhammika Manike  1970-02-03
# 75104        75680        Sriyantha Dissanayake  1969-04-03
# 89418        90135             Mariyan Dimitrov  1972-06-11
# 93980        94739                Sri Indriyani  1978-11-12
# 122419      124511                 Triyaningsih  1987-05-15
# 133132      136057    Padasak Tanviriyavechakul  1996-05-17
# 135604      138818            Arina Kupriyanova  2002-08-27
# ...
