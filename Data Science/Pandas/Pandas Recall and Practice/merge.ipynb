# %%
import pandas as pd

# %%
bios = pd.read_csv("bios.csv")
nocs = pd.read_csv("noc_regions.csv")

# %%
new_df = pd.merge(bios,nocs, left_on="born_country", right_on="NOC", how="left") #its actually database join

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
new_df.head() #here we can see the joined table
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y  region notes
# 0  1960-10-02   FRA  France   NaN
# 1         NaN   FRA  France   NaN
# 2  1994-07-17   FRA  France   NaN
# 3  1978-03-20   FRA  France   NaN
# ...

# %%
new_df.rename(columns={"region":"born_country_full"}, inplace=True) #inplace for modify the original df.
new_df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y born_country_full notes
# 0  1960-10-02   FRA            France   NaN
# 1         NaN   FRA            France   NaN
# 2  1994-07-17   FRA            France   NaN
# ...

# %%
dhaka = bios[bios["born_region"] == "Dhaka"]
khulna = bios[bios["born_region"]== "Khulna"]

# %%
ban=pd.concat([dhaka,khulna]) #its actually add two dataframe one after another and make one dataframe. 
ban
# Out:
#         athlete_id               name   born_date      born_city born_region  \
# 21999        22158      Cecil Kershaw  1895-02-03  Dhaka (Dacca)       Dhaka
# 25614        25806    Subimal Goswami  1938-01-15    Kishoreganj       Dhaka
# 119401      121209     Mohammed Milon  1993-02-25  Dhaka (Dacca)       Dhaka
# 129991      132640    Siddikur Rahman  1984-11-20  Dhaka (Dacca)       Dhaka
# 129992      132641  Abdullah Hel Baki  1989-08-01        Gazipur       Dhaka
# 68712        69229    William Knyvett  1882-05-28        Jessore      Khulna
# 119426      121236      Sharmin Ratna  1988-03-24         Magura      Khulna
# 126742      129123        Shamoli Ray  1994-04-05         Narail      Khulna
# 126743      129124       Shirin Akter  1994-10-12       Satkhira      Khulna
# 129990      132639      Masbah Ahmmed  1995-03-11       Bagerhat      Khulna
#
#        born_country            NOC  height_cm  weight_kg   died_date
# ...
